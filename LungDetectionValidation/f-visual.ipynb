# %%
import json

# %%
file_name = 'parsed-mixed_test-overjoyed-hen-305'
data_list_file_path = f'/data/output/validation/{file_name}.json'
f = open(data_list_file_path)
data = json.load(f)

print(data['test'][0].keys())
# Out:
# dict_keys(['true_box', 'pred_box', 'score', 'image'])

# %%
data['test'][0]
# Out:
# {'true_box': [[-85.06548421,
#    81.6029288,
#    -149.5488028,
#    5.285669845,
#    5.285669845,
#    5.285669845]],
#  'pred_box': [[115.67823791503906,
#    -26.664642333984375,
#    -227.63031005859375,
#    8.3056640625,
#    8.4375,
#    8.984375],
#   [-84.77830505371094,
#    81.70449829101562,
#    -149.93499755859375,
#    4.74609375,
#    4.74609375,
#    4.6875],
#   [37.47755432128906,
#    38.066802978515625,
#    -118.52874755859375,
#    38.3203125,
#    36.474609375,
#    40.9375],
#   [-10.818344116210938,
#    120.68399047851562,
#    -102.51312255859375,
#    8.876953125,
#    9.31640625,
#    10.46875],
#   [-9.719711303710938,
#    103.36953735351562,
#    -59.23187255859375,
#    9.31640625,
#    9.66796875,
#    10.15625],
#   [-111.76072692871094,
#    -48.461517333984375,
#    -280.88714599609375,
#    8.0859375,
#    8.4375,
#    8.818359375],
#   [-33.71385192871094,
#    -65.42440795898438,
#    -194.85687255859375,
#    7.734375,
#    7.91015625,
# ...
