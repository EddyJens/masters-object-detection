# %%
# %matplotlib inline

import numpy as np
import SimpleITK as sitk
import glob

import matplotlib.pyplot as plt


INPUT_FOLDER = r'D:/masters_datasets/LUNA16-original/LUNA16_Images/*.mhd'
exams = glob.glob(INPUT_FOLDER)
print(len(exams))
exams.sort()
# Out:
# 888

# %%
itkimage = sitk.ReadImage(exams[21])
ct_scan = sitk.GetArrayFromImage(itkimage)
origin = np.array(list(reversed(itkimage.GetOrigin())))
spacing = np.array(list(reversed(itkimage.GetSpacing())))

# %%
def load_scan(path):
  itkimage = sitk.ReadImage(path)
  return sitk.GetArrayFromImage(itkimage)

# %%
first_exam_pixels = load_scan(exams[21])
plt.hist(first_exam_pixels.flatten(), bins=80, color='c')
plt.xlabel("Hounsfield Units (HU)")
plt.ylabel("Frequency")
plt.show()

plt.imshow(first_exam_pixels[80], cmap=plt.cm.gray)
plt.show()

# %%
import imageio

im = first_exam_pixels[80]
imageio.imwrite('16bit.png', im.astype(np.uint16))
