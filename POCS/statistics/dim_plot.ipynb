# %%
import pandas as pd

# %%
luna = pd.read_csv('luna16-shape.csv')
hist = luna.hist(bins=30, column='z')

# %%
hc = pd.read_csv('hc-shape.csv')
hist = hc.hist(bins=30, column='z')

# %%
msd = pd.read_csv('msd-shape.csv')
hist = msd.hist(bins=30, column='z')
